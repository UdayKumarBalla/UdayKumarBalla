# %% [markdown]
# # **HxGN EAM Python Studio Python Template**

# %% [markdown]
# ##### Copyright
#
# Copyright © 2022 Hexagon AB and/or its subsidiaries and affiliates. All rights reserved.
#
# This computer program, including software, icons, graphic symbols, documentation, file formats, and audio-visual displays; may be used only as pursuant to applicable software license agreement; contains confidential and proprietary information of Hexagon AB and/or third parties which is protected by patent, trademark, copyright law, trade secret law, and international treaty, and may not be provided or otherwise made available without proper authorization from Hexagon AB and/or its subsidiaries and affiliates.
#
# ##### Modification Rights
#
# The template is subject to the Software License Agreement provided with the software.  Customer may modify this template for its internal business purposes only.

# %% [markdown]
# ## Description
#
# This notebook is the template that should be used for developing python applications for execution on the HxGN Python Framework. Copy the template file and save it with a file extension of .ipynb.
#
#
#
# For execution, the notebook file will go through a publish process where the python code is extracted into a main.py file and all the dependent packages will be listed in a requirements.txt file. The files will be zipped into a file named the same as the notebook with a .zip file extension.
#
#
#
# Note: There could be differences in how the application functions within Python Studio and execution. For example, print statements are directed to standard out and appears in the console of Python Studio but is not be accessible in batch execution. Use HxGN EAM Library log function when possible.
#
#
#
# ---

# %% [markdown]
# ## Import Section
#
# Place all import statements in this section for the python packages required by the application.

# %%
import hxgn_eam as eam
import smtplib
from email.message import EmailMessage

# %%
# Parameters
email_subject = 'Python Test Mail - Hertz - Hexagon Project team'
email_to_list = 'Udayakumar.balla@hexagon.com' #,saireddy.velagala@hexagon.com'
email_body = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Hertz - Hexagon Project Team</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background-color: black;
            margin: 0;
            padding: 20px;
        }
        h2 {
            color: #333;
            text-align: left;
        }
        table {
            width: 80%;
            margin: 20px auto;
            border-collapse: collapse;
            box-shadow: 0 2px 8px rgba(0, 0, 0, 0.1);
            background-color: #fff;
        }
        th, td {
            padding: 12px 15px;
            border: 1px solid #ddd;
            text-align: center;
        }
        th {
            background-color: #009879;
            color: #ffffff;
            text-transform: uppercase;
        }
        tr {
            border-bottom: 1px solid #dddddd;
        }
        tr:nth-of-type(even) {
            background-color: #f3f3f3;
        }
        tr:last-of-type {
            border-bottom: 2px solid #009879;
        }
        tr:hover {
            background-color: #f1f1f1;
        }
        img {
            width: 150px;
            height: 50px;
            border-radius: 0%;
        }
    </style>
</head>
<body>

   <!-- <h2><img src="https://images.hertz.com/misc/overlay/hertz-logo-black.png" alt="Hertz Logo">Hertz - Hexagon Project Team</h2> -->
    <h2><img width="250" height="50" src="data:image/gif;base64,..."/>  Hertz - Hexagon Project team</h2>
    <table>
        <thead>
            <tr>
                <th>ID</th>
                <th>Name</th>
                <th>Designation</th>
                <th>Country</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td>1</td>
                <td>Sahil Mehra</td>
                <td>Solution Architect</td>
                <td>USA</td>
            </tr>
            <tr>
                <td>2</td>
                <td>Manish Shakya</td>
                <td>Senior Implementation Consultant</td>
                <td>USA</td>
            </tr>
            <tr>
                <td>3</td>
                <td>Binoy Vithayathil</td>
                <td>Senior Implementation Consultant</td>
                <td>USA</td>
            </tr>
            <tr>
                <td>4</td>
                <td>Sai Velagala</td>
                <td>Senior Implementation Analyst</td>
                <td>India</td>
            </tr>
            <tr>
                <td>5</td>
                <td>UdayaKumar Balla</td>
                <td>Principal Implementation Consultant</td>
                <td>India</td>
            </tr>
        </tbody>
    </table>

</body>
</html>
"""
smtpserver = 'smtp210.eam.hxgnsmartcloud.com'

# %% [markdown]
# ---
#
#
#
# ## User Defined Function Section
#
# The notebook can contain user defined functions. All user defined functions should be defined in the section below. There cannot be a main function in this section.

# %%
# Functions Definition 
def sendemail():
    eam.log("in sendemail method start")
    msg = EmailMessage()
    msg['Subject'] = email_subject
    msg['From'] = 'noreply@hxgnsmartcloud.com'
    msg['To'] = email_to_list
    msg.add_alternative(email_body, subtype='html')
    # Connect to the email server
    with smtplib.SMTP(smtpserver) as server:
        server.send_message(msg)
    eam.log("in sendemail method end")

# %% [markdown]
# ---
#
# ## Python Application Entry Point
#
#
#
# This section should have only one function named main. This is the entry point for the application. This function can be edited to add user defined code and that code can call the user defined functions above. This function cannot be renamed and the parameter cannot be changed.

# %%
def main(request=None):
    # User code starts here. Note that the print example below will display in the console 
    # when run in Python Studio but will not be accessible when run in batch execution.
    eam.log("Execution Starts!!!")
    sendemail()
    eam.log("Execution Ends!!!")
    
if __name__ == "__main__":
    #execute the script
    main()
# Out:
# Execution Starts!!!
# in sendemail method start
# in sendemail method end
# Execution Ends!!!
